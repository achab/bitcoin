# %%
import numpy as np
import pandas as pd

# %%
import Quandl
#btc_exc = ['BITSTAMPUSD', 'BTCNCNY', 'BTCEEUR', 'BTCEUSD']
mydata = Quandl.get("BITCOIN/BITSTAMPUSD", returns="pandas")

# %%
mydata.tail()
# Out:
#               Open    High     Low   Close  Volume (BTC)  Volume (Currency)  \
# Date
# 2015-06-22  243.60  247.99  242.64  246.00   5149.763859     1263921.544389
# 2015-06-23  245.99  247.25  242.14  243.74   4953.903396     1210524.765819
# 2015-06-24  243.85  243.99  238.20  240.19   6723.313324     1621933.956614
# 2015-06-25  240.19  242.90  239.18  241.98   5002.931302     1207599.940886
# 2015-06-26  242.08  242.08  241.41  241.82     24.263638        5864.290873
#
#             Weighted Price
# Date
# 2015-06-22      245.432913
# 2015-06-23      244.357766
# 2015-06-24      241.240275
# 2015-06-25      241.378478
# 2015-06-26      241.690501

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(np.log(mydata['Weighted Price']))

# %%
plt.plot(np.log(mydata['Volume (Currency)']))

# %%
plt.plot(np.log(mydata['Volume (BTC)']))
