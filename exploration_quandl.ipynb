# %%
import numpy as np
import pandas as pd

# %%
import Quandl
btc_exc = ['BITSTAMPUSD', 'BTCNCNY', 'BTCEEUR', 'BTCEUSD']
mydata = Quandl.get("BITCOIN/BTCNCNY", returns="pandas")

# %%
mydata.tail()
# Out:
#                Open     High      Low    Close  Volume (BTC)  \
# Date
# 2015-06-19  1563.19  1577.00  1504.02  1518.76    24615.3363
# 2015-06-20  1519.16  1534.95  1488.39  1526.50    20599.7972
# 2015-06-21  1526.39  1531.29  1498.20  1516.39    12366.7940
# 2015-06-22  1516.14  1548.00  1510.00  1540.41    14276.6510
# 2015-06-23  1541.66  1542.95  1533.70  1538.00      600.9917
#
#             Volume (Currency)  Weighted Price
# Date
# 2015-06-19    38116183.875539     1548.473009
# 2015-06-20    31121655.712437     1510.774859
# 2015-06-21    18730296.927694     1514.563672
# 2015-06-22    21847673.883740     1530.308045
# 2015-06-23      924340.855845     1538.025992

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(mydata['Weighted Price'])

# %%
plt.plot(np.log(mydata['Volume (Currency)']))

# %%
plt.plot(np.log(mydata['Volume (BTC)']))
